# %%
import numpy as np
import scipy.stats

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return  m-h, m+h

data_16 = [
    [5.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000],
    [0.000000,  1.000000,  1.000000,  1.000000,  1.000000,  0.000000,  0.000000,  0.000000,  0.000000,  0.000000],
    [3.000000,  2.000000,  2.000000,  2.000000,  2.000000,  3.000000,  3.000000,  2.000000,  2.000000,  2.000000],
    [402.000000,  348.000000,  348.000000,  344.000000,  345.000000,  337.000000,  338.000000,  357.000000,  341.000000,  342.000000],  
    [606.000000,  657.000000,  603.000000,  601.000000,  637.000000,  594.000000,  608.000000,  596.000000,  594.000000,  596.000000],  
    [944.000000,  939.000000,  940.000000,  933.000000,  929.000000,  944.000000,  923.000000,  921.000000,  934.000000,  942.000000],  
    [1378.000000,  1378.000000,  1372.000000,  1378.000000,  1415.000000,  1353.000000,  1361.000000,  1369.000000,  1365.000000,  1367.000000],  
    [1977.000000,  2003.000000,  1982.000000,  4905.000000,  5002.000000,  1940.000000,  1967.000000,  1945.000000,  1957.000000,  1968.000000],
    [2701.000000,  2673.000000,  2680.000000,  2733.000000,  2677.000000,  2678.000000,  2688.000000,  2686.000000,  2713.000000,  2707.000000]  
]

size = [ 10, 50, 100, 500, 600, 700, 800, 900, 1000]

for i,j in zip(data_16, size):
    print(f"Размер: {j}, Доверительный интервал: {mean_confidence_interval(i)}")
# Out:
# Размер: 10, Доверительный интервал: (-0.6310785813704958, 1.6310785813704958)
# Размер: 50, Доверительный интервал: (0.030591282220162996, 0.769408717779837)
# Размер: 100, Доверительный интервал: (1.9544497855950955, 2.645550214404904)
# Размер: 500, Доверительный интервал: (336.5443631692042, 363.8556368307958)
# Размер: 600, Доверительный интервал: (594.1461226097192, 624.2538773902809)
# Размер: 700, Доверительный интервал: (928.9011352946148, 940.8988647053851)
# Размер: 800, Доверительный интервал: (1361.6859722762306, 1385.5140277237692)
# Размер: 900, Доверительный интервал: (1663.681053856129, 3465.518946143871)
# Размер: 1000, Доверительный интервал: (2679.7360952510844, 2707.4639047489154)
